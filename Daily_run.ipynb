# %%
#!/usr/bin/env python
import numpy as np
import pandas as pd
import time
import csv
import re
import json
import xlrd
import os
from datetime import datetime, date, timedelta
import nltk
#from flatten_json import flatten
regex = re.compile(r"\[|\]|<", re.IGNORECASE)
import time
import copy



def load_n_explode(file_res="API_results_" + time.strftime("%Y%m%d") + ".csv"):
    # file_res = "API_results_20210823.csv"
    my_df = pd.read_csv(file_res, error_bad_lines=False)

    ## Categories
    # my_df["Categories"]
    # Willnjust keep 2 levels.
    my_df["Categories"] = my_df["Categories"].map(eval, na_action='ignore')
    new_df = my_df["Categories"].apply(pd.Series)
    my_df["Categories"] = new_df[0].apply(pd.Series).UrlFriendlyName
    my_df["Sub_Categories"] = new_df[1].apply(pd.Series).UrlFriendlyName


    ###********NEW> LIMIT TO WINES ONLY
    my_df = my_df[my_df['Categories'].isin(['red-wine', 'white-wine'])]
    
    ## WORK AROUND> NOT SURE WHY. TODO
    my_df = my_df[my_df['Stockcode'] != 'ER_2000003422_RX2386']
    my_df = my_df[my_df['Stockcode'] != 'ER_1000004375_CALSG16']
    my_df = my_df[my_df['AdditionalDetails'] != '[]']


    ## Reviews
    my_df["Reviews"] = my_df["Reviews"].map(eval, na_action='ignore')
    # Try with first 2 reviews
    new_df = my_df["Reviews"].apply(pd.Series)
    # First
    my_df["Review1_auth"] = new_df[0].apply(pd.Series).author.apply(pd.Series).Value
    my_df["Review1_authorcontent"] = new_df[0].apply(pd.Series).authorcontent.apply(pd.Series).Value
    my_df["Review1_points"] = new_df[0].apply(pd.Series).points.apply(pd.Series).Value
    try:
        my_df["Review1_source"] = new_df[0].apply(pd.Series).source.apply(pd.Series).Value
    except:
        my_df["Review1_source"] = ""
    try:
        my_df["Review1_text"] = new_df[0].apply(pd.Series).text.apply(pd.Series).Value
    except:
        my_df["Review1_text"] = ""
    try:
        my_df["Review1_vintage"] = new_df[0].apply(pd.Series).vintage.apply(pd.Series).Value
    except:
        my_df["Review1_vintage"] = ""
        
    # Second
    my_df["Review2_auth"] = new_df[1].apply(pd.Series).author.apply(pd.Series).Value
    my_df["Review2_authorcontent"] = new_df[1].apply(pd.Series).authorcontent.apply(pd.Series).Value
    my_df["Review2_points"] = new_df[1].apply(pd.Series).points.apply(pd.Series).Value
    try:
        my_df["Review2_source"] = new_df[1].apply(pd.Series).source.apply(pd.Series).Value
    except:
        my_df["Review2_source"] = ""
    try:
        my_df["Review2_text"] = new_df[1].apply(pd.Series).text.apply(pd.Series).Value
    except:
        my_df["Review2_text"] =""
    try:
        my_df["Review2_vintage"] = new_df[1].apply(pd.Series).vintage.apply(pd.Series).Value
    except:
        my_df["Review2_vintage"] = ""
    
    # Drop reviews
    my_df = my_df.drop('Reviews', 1)

    # Illl make a deep copy for later
    full_df = copy.deepcopy(my_df)
    # full_df = full_df

    # Additional details
    my_df["AdditionalDetails"] = my_df["AdditionalDetails"].map(eval, na_action='ignore')
    # Can't use nested lists of JSON objects in pd.json_normalize
    my_df = my_df.explode(column="AdditionalDetails").reset_index(drop=True)

    # Hacky, but it works... so we wont be touching this stuff!
    add_df = pd.DataFrame(pd.json_normalize(my_df["AdditionalDetails"]))
    del add_df["DisplayName"]
    df = pd.concat([my_df, add_df], axis=1)
    df = df.pivot(index='Stockcode', columns='Name', values='Value').reset_index().drop_duplicates(subset=['Stockcode'],
                                                                                                   keep=False)

      
    # Check point, and also a way to get rid of headers
    newdf = pd.merge(full_df, df, on='Stockcode')
    newdf["Mystery"] = newdf["Description"].str.contains("Wraps")
    # This is an old secret seleciton one. Only two, so will drop them
    newdf = newdf[~newdf["Description"].str.contains("Secret Selection")]
    newdf = newdf[~newdf["Stockcode"].str.contains("672366")]
    # newdf = newdf.drop_duplicates(subset=['Stockcode'], keep=False)
    
    # Dropping a few columns we dont want 
    newdf = newdf.drop('ProductTags', 1)
    newdf = newdf.drop('ProductSashes', 1)
    newdf = newdf.drop('UniqueSellingProposition', 1)
    newdf = newdf.drop('ImageVariants', 1)
    newdf = newdf.drop('AvailablePackTypes', 1)
    try:
        newdf = newdf.drop('GroupedDetails.image', 1)
    except:
        print("Nothing to drop. All good.")
    try:
        newdf = newdf.drop('GroupedDetails.video', 1)
    except:
        print("Nothing to drop. All good.")
    newdf = newdf.drop('GroupedDetails.workflow', 1)
    newdf = newdf.drop('categoryleafnodeid', 1)
    # Now to drop the additional details, we no need no more.
    newdf = newdf.drop('AdditionalDetails', 1)
    
    return newdf



os.chdir('/home/stu/code/dans/files')
#input_file = "API_results_20210903.csv"
input_file = "API_results_" + time.strftime("%Y%m%d") + ".csv"
wide = load_n_explode(input_file)

user = 'root'
passw = 'MYSQLl0g1n!'
host =  '127.0.0.1'
port = 3306
database = 'dans_dev'


from sqlalchemy import create_engine
import pymysql
import pandas as pd

#sqlEngine       = create_engine('mysql+pymysql://root:@127.0.0.1/test', pool_recycle=3600)
sqlEngine = create_engine('mysql+mysqlconnector://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)
dbConnection    = sqlEngine.connect()
tableName = "raw_dans_raw_main"

try:
    frame           = wide.to_sql(tableName, dbConnection, if_exists='append', method='multi', chunksize = 1000 );
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created/updated successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-884529264f4a> in <module>
#     131 #input_file = "API_results_20210903.csv"
#     132 input_file = "API_results_" + time.strftime("%Y%m%d") + ".csv"
# --> 133 wide = load_n_explode(input_file)
#     134
#     135 user = 'root'
#
# <ipython-input-2-884529264f4a> in load_n_explode(file_res)
#      85
#      86     # Additional details
# ---> 87     my_df["AdditionalDetails"] = my_df["AdditionalDetails"].map(eval, na_action='ignore')
#      88     # Can't use nested lists of JSON objects in pd.json_normalize
#      89     my_df = my_df.explode(column="AdditionalDetails").reset_index(drop=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1152
#    1153         # mapper is a function
# -> 1154         new_values = map_f(values, mapper)
#    1155
#    1156         return new_values
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in map_f(values, f)
#    1146
#    1147                 def map_f(values, f):
# -> 1148                     return lib.map_infer_mask(values, f, isna(values).view(np.uint8))
#    1149
#    1150             else:
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in <module>
#
# KeyboardInterrupt:

# %%
os.chdir('/home/stu/code/dans')
input_file = "API_results_20211023.csv"
wide = load_n_explode(input_file)

user = 'root'
passw = 'MYSQLl0g1n!'
host =  '127.0.0.1'
port = 3306
database = 'dans_dev'


from sqlalchemy import create_engine
import pymysql
import pandas as pd

#sqlEngine       = create_engine('mysql+pymysql://root:@127.0.0.1/test', pool_recycle=3600)
sqlEngine = create_engine('mysql+mysqlconnector://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)
dbConnection    = sqlEngine.connect()
tableName = "raw_dans_raw_main"

try:
    frame           = wide.to_sql(tableName, dbConnection, if_exists='append', method='multi', chunksize = 1000 );
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created/updated successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# Table raw_dans_raw_main created/updated successfully.

# %%
import glob
path = r'/home/stu/code/dans/files' # use your path
file =  "/API_results_" + time.strftime("%Y%m%d") + ".csv"
file_res = path + file

# %%
wide.to_csv(file_res)

# %%
file_res
# Out:
# '/home/stu/code/dans/files/API_results_20211024.csv'

# %%
file =  "/API_results_" + time.strftime("%Y%m%d") + ".csv"
file_res = path + file

# %%
file_res
# Out:
# '/home/stu/code/dans/files/API_results_20211024.csv'

# %%
#sqlEngine       = create_engine('mysql+pymysql://root:@127.0.0.1/test', pool_recycle=3600)

user = 'root'
passw = 'MYSQLl0g1n!'
host =  '127.0.0.1'
port = 3306
database = 'dans_dev'
sqlEngine = create_engine('mysql+mysqlconnector://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)
dbConnection    = sqlEngine.connect()

# %%
sql = "With latest as (select Stockcode, max(ts_activity) ts_activity from raw_dans_raw_main group by Stockcode) select rdrm.* from raw_dans_raw_main rdrm, latest l where 1=1 and rdrm.Stockcode=l.Stockcode and rdrm.ts_activity=l.ts_activity ;"

# %%
df = pd.read_sql(sql, dbConnection)

# %%
df.iloc[: , 2:]
# Out:
#        index  Unnamed: 0 RecommendedProducts ProductsInSameOffer  Categories  \
# 0          0           0                None                None    red-wine
# 1          1           0                None                None  white-wine
# 2          2           0                None                None    red-wine
# 3          3           0                None                None    red-wine
# 4          4           0                None                None    red-wine
# ...      ...         ...                 ...                 ...         ...
# 23110    581           0                None                None  white-wine
# 23111    582           0                None                None    red-wine
# 23112    583           0                None                None    red-wine
# 23113    584           0                None                None  white-wine
# 23114    585           0                None                None    red-wine
#
#       BackorderMessage DeliveryOptionsInfo SavedLists   Stockcode  \
# 0        Limited stock                None       None      133780
# 1        Limited stock                None       None      334645
# 2        Limited stock                None       None      800109
# 3        Limited stock                None       None      342393
# 4        Limited stock                None       None      324024
# ...                ...                 ...        ...         ...
# 23110    Limited stock                None       None  MYSTERY627
# 23111    Limited stock                None       None  MYSTERY628
# 23112    Limited stock                None       None  MYSTERY629
# 23113    Limited stock                None       None  MYSTERY630
# 23114    Limited stock                None       None  MYSTERY631
#
#                                              Description  ...  \
# 0       Dalwhinnie Moonambel<br>Cabernet Sauvignon......  ...
# 1                      Gossips Sweet Lips Moscato  750mL  ...
# 2                           Wendouree Shiraz 1997  750mL  ...
# 3       Château Mouton Rothschild<br>Pauillac 1970  7...  ...
# 4              Tahbilk Cabernet Sauvignon<br>2005  750mL  ...
# ...                                                  ...  ...
# 23110   Under Wraps Margaret River<br>Sauvignon Blanc...  ...
# 23111   Under Wraps Great Southern<br>Cabernet Sauvig...  ...
# 23112   Under Wraps Great Southern<br>Shiraz 2019  750mL  ...
# 23113   Under Wraps Great Southern<br>Chardonnay 2019...  ...
# 23114   Under Wraps Great Southern<br>Shiraz 2018  750mL  ...
#
#                                      webtitle webtotalreviewcount webvideourl  \
# 0                Moonambel Cabernet Sauvignon                 NaN        None
# 1                          Sweet Lips Moscato               166.0        None
# 2                                 Shiraz 1997                 NaN        None
# 3                               Pauillac 1970                 NaN        None
# 4                     Cabernet Sauvignon 2005                 NaN        None
# ...                                       ...                 ...         ...
# 23110     Margaret River Sauvignon Blanc 2020                 NaN        None
# 23111  Great Southern Cabernet Sauvignon 2019                 NaN        None
# 23112              Great Southern Shiraz 2019                 NaN        None
# 23113          Great Southern Chardonnay 2019                 NaN        None
# 23114              Great Southern Shiraz 2018                 NaN        None
#
#        webvintagecurrent                                     webvintagenote  \
# 0                  2016*  * Vintages may vary from store to store and wh...
# 1                   None  * Vintages may vary from store to store and wh...
# 2                  1997*                                               None
# 3                   1970                                               None
# 4                   2005                                               None
# ...                  ...                                                ...
# 23110               None                                               None
# 23111               2019                                               None
# 23112               2019                                               None
# 23113               2019                                               None
# 23114               2018                                               None
#
#         webwinebody  webwinemaker webwinestyle  Mystery         ts_activity
# 0       Full Bodied          None          Dry        0 2021-10-24 20:41:35
# 1      Light Bodied          None   Semi Sweet        0 2021-10-24 20:41:35
# 2       Full Bodied          None          Dry        0 2021-10-24 20:41:35
# 3              None          None          Dry        0 2021-10-24 20:41:35
# 4       Full Bodied          None          Dry        0 2021-10-24 20:41:35
# ...             ...           ...          ...      ...                 ...
# 23110  Light Bodied          None          Dry        1 2021-10-24 20:41:35
# 23111          None          None         None        1 2021-10-24 20:41:35
# 23112          None          None         None        1 2021-10-24 20:41:35
# 23113          None          None         None        1 2021-10-24 20:41:35
# 23114          None          None         None        1 2021-10-24 20:41:35
#
# [23115 rows x 187 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
