# %%
#!/usr/bin/env python
import numpy as np
import pandas as pd
import time
import csv
import re
import json
import xlrd
import os
from datetime import datetime, date, timedelta
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
#from flatten_json import flatten
regex = re.compile(r"\[|\]|<", re.IGNORECASE)
import time
import copy
from fuzzywuzzy import process, fuzz


def load_n_explode(file_res="API_results_" + time.strftime("%Y%m%d") + ".csv"):
    # file_res = "API_results_20210823.csv"
    my_df = pd.read_csv(file_res, error_bad_lines=False)

    ## Categories
    # my_df["Categories"]
    # Willnjust keep 2 levels.
    my_df["Categories"] = my_df["Categories"].map(eval, na_action='ignore')
    new_df = my_df["Categories"].apply(pd.Series)
    my_df["Categories"] = new_df[0].apply(pd.Series).UrlFriendlyName
    my_df["Sub_Categories"] = new_df[1].apply(pd.Series).UrlFriendlyName


    ###********NEW> LIMIT TO WINES ONLY
    my_df = my_df[my_df['Categories'].isin(['red-wine', 'white-wine'])]
    
    ## WORK AROUND> NOT SURE WHY. TODO
    my_df = my_df[my_df['Stockcode'] != 'ER_2000003422_RX2386']
    my_df = my_df[my_df['Stockcode'] != 'ER_1000004375_CALSG16']


    ## Reviews
    my_df["Reviews"] = my_df["Reviews"].map(eval, na_action='ignore')
    # Try with first 2 reviews
    new_df = my_df["Reviews"].apply(pd.Series)
    # First
    my_df["Review1_auth"] = new_df[0].apply(pd.Series).author.apply(pd.Series).Value
    my_df["Review1_authorcontent"] = new_df[0].apply(pd.Series).authorcontent.apply(pd.Series).Value
    my_df["Review1_points"] = new_df[0].apply(pd.Series).points.apply(pd.Series).Value
    try:
        my_df["Review1_source"] = new_df[0].apply(pd.Series).source.apply(pd.Series).Value
    except:
        my_df["Review1_source"] = ""
    try:
        my_df["Review1_text"] = new_df[0].apply(pd.Series).text.apply(pd.Series).Value
    except:
        my_df["Review1_text"] = ""
    try:
        my_df["Review1_vintage"] = new_df[0].apply(pd.Series).vintage.apply(pd.Series).Value
    except:
        my_df["Review1_vintage"] = ""
        
    # Second
    my_df["Review2_auth"] = new_df[1].apply(pd.Series).author.apply(pd.Series).Value
    my_df["Review2_authorcontent"] = new_df[1].apply(pd.Series).authorcontent.apply(pd.Series).Value
    my_df["Review2_points"] = new_df[1].apply(pd.Series).points.apply(pd.Series).Value
    try:
        my_df["Review2_source"] = new_df[1].apply(pd.Series).source.apply(pd.Series).Value
    except:
        my_df["Review2_source"] = ""
    try:
        my_df["Review2_text"] = new_df[1].apply(pd.Series).text.apply(pd.Series).Value
    except:
        my_df["Review2_text"] =""
    try:
        my_df["Review2_vintage"] = new_df[1].apply(pd.Series).vintage.apply(pd.Series).Value
    except:
        my_df["Review2_vintage"] = ""
    
    # Drop reviews
    my_df = my_df.drop('Reviews', 1)

    # Illl make a deep copy for later
    full_df = copy.deepcopy(my_df)
    # full_df = full_df

    # Additional details
    my_df["AdditionalDetails"] = my_df["AdditionalDetails"].map(eval, na_action='ignore')
    # Can't use nested lists of JSON objects in pd.json_normalize
    my_df = my_df.explode(column="AdditionalDetails").reset_index(drop=True)

    # Hacky, but it works... so we wont be touching this stuff!
    add_df = pd.DataFrame(pd.json_normalize(my_df["AdditionalDetails"]))
    del add_df["DisplayName"]
    df = pd.concat([my_df, add_df], axis=1)
    df = df.pivot(index='Stockcode', columns='Name', values='Value').reset_index().drop_duplicates(subset=['Stockcode'],
                                                                                                   keep=False)

      
    # Check point, and also a way to get rid of headers
    newdf = pd.merge(full_df, df, on='Stockcode')
    newdf["Mystery"] = newdf["Description"].str.contains("Wraps")
    # This is an old secret seleciton one. Only two, so will drop them
    newdf = newdf[~newdf["Description"].str.contains("Secret Selection")]
    newdf = newdf[~newdf["Stockcode"].str.contains("672366")]
    # newdf = newdf.drop_duplicates(subset=['Stockcode'], keep=False)
    
    # Dropping a few columns we dont want 
    newdf = newdf.drop('ProductTags', 1)
    newdf = newdf.drop('ProductSashes', 1)
    newdf = newdf.drop('UniqueSellingProposition', 1)
    newdf = newdf.drop('ImageVariants', 1)
    newdf = newdf.drop('AvailablePackTypes', 1)
    try:
        newdf = newdf.drop('GroupedDetails.image', 1)
    except:
        print("Nothing to drop. All good.")
    try:
        newdf = newdf.drop('GroupedDetails.video', 1)
    except:
        print("Nothing to drop. All good.")
    newdf = newdf.drop('GroupedDetails.workflow', 1)
    newdf = newdf.drop('categoryleafnodeid', 1)
    # Now to drop the additional details, we no need no more.
    newdf = newdf.drop('AdditionalDetails', 1)
    
    return newdf



def giveaway(df):
    gives = df.copy(deep=True)
    gives = gives[['Stockcode','Description','webproductname','Prices.singleprice.Value','Prices.promoprice.Value','Prices.promoprice.BeforePromotion','Prices.promoprice.AfterPromotion','IsForDelivery']]
    gives = gives[gives.webproductname.notnull()]
    gives = gives[gives["Description"].str.contains("Wraps")]
    gives = gives[~gives["webproductname"].str.contains("Wraps")]
    gives = gives[gives["IsForDelivery"]]
    gives["METHOD"] = "giveaway"
    return gives



def ohe(df):
    #### ONE HOT ENCODED
    ##### First I split into numeric and nominal. OHE the nominal
    known=df
    exclude_col = known.select_dtypes(include=np.number).columns.tolist() + ["Stockcode"]
    my_df_num = known[exclude_col]
    my_df_cat = known.drop(exclude_col, axis=1)
    # my_df_cat.to_csv("FIN.csv")
    my_df_cat_ohe = pd.get_dummies(my_df_cat)
    my_df_ohe = pd.concat([my_df_num, my_df_cat_ohe], axis=1)
    my_df_ohe = my_df_ohe.fillna(0)
    my_df_ohe = my_df_ohe.replace(np.nan, 0)

    # Drop duplicates #TODO check whats better to keep
    my_df_ohe = my_df_ohe.loc[:, ~my_df_ohe.columns.duplicated()]
    # Clean up names
    my_df_ohe.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in
                         my_df_ohe.columns.values]

    return my_df_ohe

def get_knn(df, thresh):

    myst  = df[df["Mystery"]]
    known  = df[~df["Mystery"]]

    myst_nn = myst.drop("Stockcode", axis=1)
    myst_nn = myst_nn.drop("Mystery", axis=1)
    known_nn = known.drop("Stockcode", axis=1)
    known_nn = known_nn.drop("Mystery", axis=1)

    # Create the k-NN model using k=5
    nn_abs = NearestNeighbors(n_neighbors=1, algorithm='auto')

    # Fit it
    nn_abs.fit(known_nn)

    results_wine = []

    for index in range(len(myst.index)):
        distance, matches = nn_abs.kneighbors(myst_nn.iloc[[index]], 1, return_distance=True)
        results_wine.append(
            {
                #'Mystery': "https://www.danmurphys.com.au/product/" + str(myst['Stockcode'].iloc[[index][0]]),
                'Stockcode_x': str(myst['Stockcode'].iloc[[index][0]]),
                #'Matched': "https://www.danmurphys.com.au/product/" + str(known["Stockcode"].iloc[matches[0][0]]),
                'Stockcode_y': str(known["Stockcode"].iloc[matches[0][0]]),
                'Distance': str(distance[0][0])

            }
        )

    matched = pd.DataFrame(results_wine)
    matched["MatchLevel"] = np.where(matched['Distance'].astype(float) < float(thresh), "Good", "Poor")
    #matched = matched.sort_values(['MatchLevel', 'Savings'], ascending=[True, False])
    matched["METHOD"] = "KNN"
    return matched


def lazy_desc(df, keep1):
    #df = wide
    #keep1 = keep_nlp
    kept = df[keep1]

    kept.reset_index(drop=True, inplace=True)
    myst = kept[kept["Mystery"]]
    known = kept[~kept["Mystery"]]

    known = known[known["Review1_text"] != "[...]"]
    known = known[known["Review2_text"] != "[...]"]
    
    known = known[known["Review1_text"] != "[..]"]
    known = known[known["Review2_text"] != "[..]"]
    
    known = known[known["Review1_text"] != "[....]"]
    known = known[known["Review2_text"] != "[....]"]
 
    
    
    # Description match
    desc_match = pd.merge(myst[myst['RichDescription'].notna()], known, on=['RichDescription'], how='inner')
    desc_match["METHOD"] = "desc_match"
    # Web match
    webdesc_match = pd.merge(myst[myst['webdescriptionshort'].notna()], known, on=['webdescriptionshort'], how='inner')
    webdesc_match["METHOD"] = "webdesc_match"
    # Review match (TODO more than 2 deep)
    rev_match = pd.merge(myst[myst['Review1_text'].notna()], known, on=['Review1_text'], how='inner')
    rev_match["METHOD"] = "rev_match"
    #rev_match = rev_match[~[rev_match['Review1_text'] == [...]]]
    rev1_match = pd.merge(myst[myst['Review2_text'].notna()], known, on=['Review2_text'], how='inner')
    rev1_match["METHOD"] = "rev2_match" # I know. Using normal index for people...
    #rev_match = rev_match[~[rev_match.['Review1_text'].str.contains("[...]")]]
    text_match = desc_match.append(webdesc_match).append(rev_match).append(rev1_match).reset_index()
    text_match = text_match[['Stockcode_x', 'Stockcode_y',"METHOD"]]
    text_match["MatchLevel"] = "Good"
    return text_match


## Try Fuzzywuzzy

def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=1):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()

    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))
    df_1['matches'] = m

    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2

    return df_1

#fuzzy_merge(myst, known, 'webdescriptionshort', 'webdescriptionshort', threshold=80)


def make_clickable(val):
    # target _blank to open new window
    val1 = 'https://www.danmurphys.com.au/product/' + str(val)
    return '<a target="_blank" href="{}">{}</a>'.format(val1, val)


## CONFIG

keep_nlptdf =['Stockcode',
 'webdescriptionshort',
'RichDescription']

keep_ohe =['Categories',
 'Mystery',
 'Stockcode',
 'PackageSize',
 'Prices.inanysixprice.Message',
 'Prices.inanysixprice.Value',
 'Sub_Categories',
 'Review1_auth',
 'Review1_points',
 'Review1_source',
 'awardwinner',
 'glutenfree',
 'preservativefree',
 'varietal',
 'webalcoholpercentage',
 'webbottleclosure',
 'webcountryoforigin',
 'webfoodmatch',
 'webisorganic',
 'webisvegan',
 'webliquorsize',
 'webmaincategory',
 'webregionoforigin',
 'webstateoforigin',
 'webtotalreviewcount',
 'webwinebody',
 'webwinestyle',
 'IsForDelivery']


keep_nlp =['Categories',
 'Stockcode',
 'Mystery',
 'PackageSize',
 'RichDescription',
 'Review1_text',
 'Review2_text',
 'Prices.inanysixprice.Message',
 'Prices.inanysixprice.Value',
 'Sub_Categories',
 'Review1_auth',
 'Review1_points',
 'Review1_source',
 'awardwinner',
 'glutenfree',
 'preservativefree',
 'varietal',
 'webalcoholpercentage',
 'webbottleclosure',
 'webcountryoforigin',
 'webdescriptionshort',
 'webfoodmatch',
 'webisorganic',
 'webisvegan',
 'webliquorsize',
 'webmaincategory',
 'webregionoforigin',
 'webstateoforigin',
 'webtotalreviewcount',
 'webwinebody',
 'webwinestyle',
 'IsForDelivery']

# %%
#### RUNNING HERE

#input_file = "API_results_" + time.strftime("%Y%m%d") + ".csv"
os.chdir('/home/stu/code/dans')
input_file = "API_results_20211002.csv"
wide = load_n_explode(input_file)
# Out:
# Nothing to drop. All good.

# %%
prev.Categories
# Out:
# 0          red-wine
# 1        white-wine
# 2          red-wine
# 3          red-wine
# 4          red-wine
#             ...
# 22599      red-wine
# 22600      red-wine
# 22601      red-wine
# 22602      red-wine
# 22603      red-wine
# Name: Categories, Length: 22531, dtype: object

# %%
input_file = "previous.csv"
prev = load_n_explode(input_file)

# %%
prev.to_csv("Previous_loaded.csv")

# %%
#from pandas.io import sql
#import MySQLdb

user = 'root'
passw = 'MYSQLl0g1n!'
host =  '127.0.0.1'
port = 3306
database = 'dans_dev'

#conn = MySQLdb.connect(host=host,
#                       port=port,
#                       user=user, 
#                       passwd=passw,  
#                       db=database,
#                       charset='utf8', 
#                       auth_plugin='mysql_native_password')

# %%
#import mysql.connector
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)
#prev.to_sql(name='sample_table2', con=conn, if_exists = 'append', index=False)

# %%
#data.to_sql(name=database, con=conn, if_exists = 'replace', index=False, flavor = 'mysql')
#prev.to_sql(con=conn, name='main_raw', flavor='mysql')
wide.to_sql(name=database, con=conn, if_exists = 'append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d75105969346> in <module>
#       1 #data.to_sql(name=database, con=conn, if_exists = 'replace', index=False, flavor = 'mysql')
#       2 #prev.to_sql(con=conn, name='main_raw', flavor='mysql')
# ----> 3 wide.to_sql(name=database, con=conn, if_exists = 'append', index=False)
#
# NameError: name 'conn' is not defined

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#sqlEngine       = create_engine('mysql+pymysql://root:@127.0.0.1/test', pool_recycle=3600)
sqlEngine = create_engine('mysql+mysqlconnector://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)
dbConnection    = sqlEngine.connect()

try:
    frame           = prev.to_sql("raw_dans_all", dbConnection, if_exists='replace', method='multi', chunksize = 1000 );
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-2eb9756e391d> in <module>
#      14     print(ex)
#      15 else:
# ---> 16     print("Table %s created successfully."%tableName);
#      17 finally:
#      18     dbConnection.close()
#
# NameError: name 'tableName' is not defined

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

#sqlEngine       = create_engine('mysql+pymysql://root:@127.0.0.1/test', pool_recycle=3600)
sqlEngine = create_engine('mysql+mysqlconnector://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)
dbConnection    = sqlEngine.connect()

try:
    frame           = wide.to_sql("raw_dans_new", dbConnection, if_exists='replace', method='multi', chunksize = 1000 );
except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    print("Table %s created successfully."%tableName);   
finally:
    dbConnection.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a5cff8fa7539> in <module>
#      14     print(ex)
#      15 else:
# ---> 16     print("Table %s created successfully."%tableName);
#      17 finally:
#      18     dbConnection.close()
#
# NameError: name 'tableName' is not defined

# %%
a = df.applymap(lambda x: isinstance(x, list)).all()
#print (a)

# %%
print (df.applymap(type))
# Out:
#       API_results_20210906.csv: RecommendedProducts ProductsInSameOffer  \
# 0                 <class 'str'>     <class 'float'>     <class 'float'>
# 1                 <class 'str'>     <class 'float'>     <class 'float'>
# 2                 <class 'str'>     <class 'float'>     <class 'float'>
# 3                 <class 'str'>     <class 'float'>     <class 'float'>
# 4                 <class 'str'>     <class 'float'>     <class 'float'>
# ...                         ...                 ...                 ...
# 22599             <class 'str'>     <class 'float'>     <class 'float'>
# 22600             <class 'str'>     <class 'float'>     <class 'float'>
# 22601             <class 'str'>     <class 'float'>     <class 'float'>
# 22602             <class 'str'>     <class 'float'>     <class 'float'>
# 22603             <class 'str'>     <class 'float'>     <class 'float'>
#
#           Categories BackorderMessage          Reviews DeliveryOptionsInfo  \
# 0      <class 'str'>    <class 'str'>  <class 'float'>     <class 'float'>
# 1      <class 'str'>    <class 'str'>  <class 'float'>     <class 'float'>
# 2      <class 'str'>    <class 'str'>  <class 'float'>     <class 'float'>
# 3      <class 'str'>    <class 'str'>  <class 'float'>     <class 'float'>
# 4      <class 'str'>    <class 'str'>   <class 'list'>     <class 'float'>
# ...              ...              ...              ...                 ...
# 22599  <class 'str'>    <class 'str'>   <class 'list'>     <class 'float'>
# 22600  <class 'str'>    <class 'str'>   <class 'list'>     <class 'float'>
# 22601  <class 'str'>    <class 'str'>   <class 'list'>     <class 'float'>
# 22602  <class 'str'>    <class 'str'>  <class 'float'>     <class 'float'>
# 22603  <class 'str'>    <class 'str'>  <class 'float'>     <class 'float'>
#
#             SavedLists      Stockcode    Description  ... webstateoforigin  \
# 0      <class 'float'>  <class 'str'>  <class 'str'>  ...    <class 'str'>
# 1      <class 'float'>  <class 'str'>  <class 'str'>  ...  <class 'float'>
# 2      <class 'float'>  <class 'str'>  <class 'str'>  ...    <class 'str'>
# 3      <class 'float'>  <class 'str'>  <class 'str'>  ...  <class 'float'>
# 4      <class 'float'>  <class 'str'>  <class 'str'>  ...    <class 'str'>
# ...                ...            ...            ...  ...              ...
# 22599  <class 'float'>  <class 'str'>  <class 'str'>  ...    <class 'str'>
# 22600  <class 'float'>  <class 'str'>  <class 'str'>  ...  <class 'float'>
# 22601  <class 'float'>  <class 'str'>  <class 'str'>  ...    <class 'str'>
# 22602  <class 'float'>  <class 'str'>  <class 'str'>  ...    <class 'str'>
# 22603  <class 'float'>  <class 'str'>  <class 'str'>  ...  <class 'float'>
#
#             webtitle webtotalreviewcount      webvideourl webvintagecurrent  \
# 0      <class 'str'>     <class 'float'>  <class 'float'>     <class 'str'>
# 1      <class 'str'>       <class 'int'>  <class 'float'>   <class 'float'>
# 2      <class 'str'>     <class 'float'>  <class 'float'>     <class 'str'>
# 3      <class 'str'>     <class 'float'>  <class 'float'>     <class 'str'>
# 4      <class 'str'>     <class 'float'>  <class 'float'>     <class 'str'>
# ...              ...                 ...              ...               ...
# 22599  <class 'str'>     <class 'float'>  <class 'float'>     <class 'str'>
# 22600  <class 'str'>     <class 'float'>  <class 'float'>     <class 'str'>
# 22601  <class 'str'>       <class 'int'>    <class 'str'>   <class 'float'>
# 22602  <class 'str'>       <class 'int'>  <class 'float'>     <class 'str'>
# 22603  <class 'str'>     <class 'float'>  <class 'float'>     <class 'str'>
#
#         webvintagenote      webwinebody     webwinemaker   webwinestyle  \
# 0        <class 'str'>    <class 'str'>  <class 'float'>  <class 'str'>
# 1        <class 'str'>    <class 'str'>  <class 'float'>  <class 'str'>
# 2      <class 'float'>    <class 'str'>  <class 'float'>  <class 'str'>
# 3      <class 'float'>  <class 'float'>  <class 'float'>  <class 'str'>
# 4      <class 'float'>    <class 'str'>  <class 'float'>  <class 'str'>
# ...                ...              ...              ...            ...
# 22599  <class 'float'>    <class 'str'>  <class 'float'>  <class 'str'>
# 22600  <class 'float'>    <class 'str'>  <class 'float'>  <class 'str'>
# 22601    <class 'str'>    <class 'str'>    <class 'str'>  <class 'str'>
# 22602    <class 'str'>    <class 'str'>    <class 'str'>  <class 'str'>
# 22603    <class 'str'>    <class 'str'>  <class 'float'>  <class 'str'>
#
#               Mystery
# 0      <class 'bool'>
# 1      <class 'bool'>
# 2      <class 'bool'>
# 3      <class 'bool'>
# 4      <class 'bool'>
# ...               ...
# 22599  <class 'bool'>
# 22600  <class 'bool'>
# 22601  <class 'bool'>
# 22602  <class 'bool'>
# 22603  <class 'bool'>
#
# [22531 rows x 195 columns]

# %%
## Get the easy matches
gives = giveaway(wide)
lazy = lazy_desc(wide,keep_nlp)

#now the OHE and KNN
ohe_file = ohe(wide[keep_ohe])
knns = get_knn(ohe_file,1.8)

# Cleanup and save it
matches = knns.append(lazy)

# %%
#matches_to = copy.deepcopy(matches)

# %%
matches = matches[matches.MatchLevel.str.contains("Good")] # Get ride of bad matches first
avail = wide[wide["IsForDelivery"]][["Stockcode","Mystery",'varietal','webbottleclosure','Prices.singleprice.Value','Prices.promoprice.Value','Prices.promoprice.BeforePromotion','Prices.promoprice.AfterPromotion']]

# %%
matches = pd.merge(avail,matches, left_on='Stockcode', right_on="Stockcode_x")

# %%
# Check if its in stock
matches["Savings"] = matches['Prices.promoprice.BeforePromotion'] - matches['Prices.promoprice.AfterPromotion']
matches = pd.merge(matches, wide[["Description","Stockcode"]], left_on='Stockcode_y', right_on="Stockcode",how='left')

# %%
matches = matches[['Stockcode_x', 'Stockcode_y', 'Description', 'varietal','webbottleclosure','Prices.promoprice.BeforePromotion', 'Prices.promoprice.AfterPromotion', 'Savings']]

# %%
myst = wide[wide["Mystery"]]
myst["Savings"] = myst['Prices.promoprice.BeforePromotion'] - myst['Prices.promoprice.AfterPromotion']
myst =  pd.merge(avail,myst, left_on='Stockcode', right_on="Stockcode")
myst = myst[["Stockcode",'Description','varietal_x','webbottleclosure_x','Prices.promoprice.BeforePromotion_x', 'Prices.promoprice.AfterPromotion_x', 'Savings' ]]
myst = myst[["Stockcode",'Description','varietal_x','webbottleclosure_x','Prices.promoprice.BeforePromotion_x', 'Prices.promoprice.AfterPromotion_x', 'Savings' ]]
myst = myst.sort_values(['Savings'], ascending=[False])
# Out:
# /home/stu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
myst
# Out:
#                          Stockcode  \
# 69         ER_1000003887_UW-194022
# 83   ER_2000003549_UWVINBVSHIRAZ18
# 36            ER_1000004523_P01336
# 33         ER_1000003887_UW-203062
# 27         ER_1000003887_UW-203063
# ..                             ...
# 156    ER_2000003442_9352510000332
# 157  ER_2000003439_MORV-19-SHZ-MCV
# 158                     MYSTERY540
# 160                     MYSTERY467
# 168                     MYSTERY107
#
#                                            Description          varietal_x  \
# 69      Under Wraps Mclaren Vale<br>Shiraz 2015  750mL              Shiraz
# 83    Under Wraps Southern Barossa<br>Valley Shiraz...              Shiraz
# 36      Under Wraps Mclaren Vale<br>Shiraz 2016  750mL              Shiraz
# 33    Under Wraps Margaret River<br>Chardonnay 2019...          Chardonnay
# 27    Under Wraps Margaret River<br>Cabernet Blend....  Cabernet Sauvignon
# ..                                                 ...                 ...
# 156       Under Wraps Limestone Coast<br>Malbec  750mL              Malbec
# 157   Under Wraps Reserve Mclaren<br>Vale Shiraz 20...              Shiraz
# 158   Under Wraps Clare Valley<br>Cabernet Sauvigno...  Cabernet Sauvignon
# 160   Under Wraps Western<br>Australia Merlot... 750mL              Merlot
# 168   Under Wraps Fifth Growth<br>Bordeaux Blend......        Bordeaux Red
#
#     webbottleclosure_x  Prices.promoprice.BeforePromotion_x  \
# 69           Screw Cap                              1410.00
# 83                Cork                               479.94
# 36           Screw Cap                               604.14
# 33           Screw Cap                               510.00
# 27           Screw Cap                               660.00
# ..                 ...                                  ...
# 156          Screw Cap                                  NaN
# 157          Screw Cap                                  NaN
# 158          Screw Cap                                  NaN
# 160          Screw Cap                                  NaN
# 168                NaN                                  NaN
#
#      Prices.promoprice.AfterPromotion_x  Savings
# 69                                810.0   600.00
# 83                                210.0   269.94
# 36                                360.0   244.14
# 33                                285.0   225.00
# 27                                450.0   210.00
# ..                                  ...      ...
# 156                                 NaN      NaN
# 157                                 NaN      NaN
# 158                                 NaN      NaN
# 160                                 NaN      NaN
# 168                                 NaN      NaN
#
# [172 rows x 7 columns]

# %%
matches = matches[['Stockcode_x', 'Stockcode_y', 'Description', 'varietal','webbottleclosure','Prices.promoprice.BeforePromotion', 'Prices.promoprice.AfterPromotion', 'Savings']]
matches = matches.sort_values(['Savings'], ascending=[False])

matches = matches.loc[:,~matches.columns.duplicated()]

matches = matches.drop_duplicates()


csv_file = "Match_results" + time.strftime("%Y%m%d") + ".csv"
matches.to_csv(csv_file)

# %%
# Out:
#                          Stockcode  \
# 0          ER_1000003887_UW-194022
# 1    ER_2000003549_UWVINBVSHIRAZ18
# 2             ER_1000004523_P01336
# 3          ER_1000003887_UW-203062
# 4          ER_1000003887_UW-203063
# ..                             ...
# 167    ER_2000003442_9352510000332
# 168  ER_2000003439_MORV-19-SHZ-MCV
# 169                     MYSTERY540
# 170                     MYSTERY467
# 171                     MYSTERY107
#
#                                            Description          varietal_x  \
# 0       Under Wraps Mclaren Vale<br>Shiraz 2015  750mL              Shiraz
# 1     Under Wraps Southern Barossa<br>Valley Shiraz...              Shiraz
# 2       Under Wraps Mclaren Vale<br>Shiraz 2016  750mL              Shiraz
# 3     Under Wraps Margaret River<br>Chardonnay 2019...          Chardonnay
# 4     Under Wraps Margaret River<br>Cabernet Blend....  Cabernet Sauvignon
# ..                                                 ...                 ...
# 167       Under Wraps Limestone Coast<br>Malbec  750mL              Malbec
# 168   Under Wraps Reserve Mclaren<br>Vale Shiraz 20...              Shiraz
# 169   Under Wraps Clare Valley<br>Cabernet Sauvigno...  Cabernet Sauvignon
# 170   Under Wraps Western<br>Australia Merlot... 750mL              Merlot
# 171   Under Wraps Fifth Growth<br>Bordeaux Blend......        Bordeaux Red
#
#     webbottleclosure_x  Prices.promoprice.BeforePromotion_x  \
# 0            Screw Cap                              1410.00
# 1                 Cork                               479.94
# 2            Screw Cap                               604.14
# 3            Screw Cap                               510.00
# 4            Screw Cap                               660.00
# ..                 ...                                  ...
# 167          Screw Cap                                  NaN
# 168          Screw Cap                                  NaN
# 169          Screw Cap                                  NaN
# 170          Screw Cap                                  NaN
# 171                NaN                                  NaN
#
#      Prices.promoprice.AfterPromotion_x  Savings
# 0                                 810.0   600.00
# 1                                 210.0   269.94
# 2                                 360.0   244.14
# 3                                 285.0   225.00
# 4                                 450.0   210.00
# ..                                  ...      ...
# 167                                 NaN      NaN
# 168                                 NaN      NaN
# 169                                 NaN      NaN
# 170                                 NaN      NaN
# 171                                 NaN      NaN
#
# [172 rows x 7 columns]

# %%
matches = matches.sort_values(['Savings'], ascending=[False])

matches = matches.loc[:,~matches.columns.duplicated()]

matches = matches.drop_duplicates()


csv_file = "Match_results" + time.strftime("%Y%m%d") + ".csv"
matches.to_csv(csv_file)

from datetime import date, timedelta  
yesterday = date.today() - timedelta(days=1) 
today = date.today()   
file_yes = "Match_results" + yesterday.strftime("%Y%m%d") + ".csv" 
file_tod = "Match_results" + today.strftime("%Y%m%d") + ".csv"
df1 = pd.read_csv(file_yes).iloc[:, 1:]
df2 = pd.read_csv(file_tod).iloc[:, 1:]
df_diff = pd.concat([df1,df2]).drop_duplicates(keep=False)

matches = df_diff
matches.reset_index(drop=True, inplace=True)

final = matches.style.format({'Stockcode_x': make_clickable, 'Stockcode_y': make_clickable, }) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .hide_index()


# Now complete list
myst.reset_index(drop=True, inplace=True)

final_myst = myst.style.format({'Stockcode': make_clickable }) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .hide_index()


#writing HTML Content
heading = '<h1> Mystery Wines</h1>'
subheading = '<h3> Matched </h3>'
# Using .now() from datetime library to add Time stamp
now = datetime.now()
current_time = now.strftime("%m/%d/%Y %H:%M:%S")
header = '<div class="top">' + heading + subheading +'</div>'
footer = '<div class="bottom"> <h3> This Report has been Generated on'+ current_time +'</h3> </div>'
content = final
content_2 = final_myst
# Concating everything to a single string

html = header + content.render() + footer
html_file = "Match_new.html"
with open(html_file,'w+') as file:
    file.write(html)


html = header + content_2.render()  + footer
html_file = "All_deals.html"
with open(html_file,'w+') as file:
    file.write(html)

# %%
matches
# Out:
#                       Stockcode_x                    Stockcode_y  \
# 0         ER_1000003887_UW-203062            ER_1000007652_ACH10
# 1         ER_1000003887_UW-203063        ER_2000003490_PW142PCAS
# 2                      MYSTERY596                         119852
# 3     ER_1000006495_UW-219-MVSHIR     ER_1000004900_ZF18AESH76D1
# 4      ER_1000006495_UWAPOMVCAB19              ER_1000006495_226
# ..                            ...                            ...
# 75     ER_2000003499_MYSTERYMCS19          ER_2000003499_9269708
# 76                     MYSTERY400                          76525
# 77  ER_2000003439_MORV-17-SHZ-BAR      ER_2000003129_QUARRYSHZ18
# 78  ER_2000003439_MORV-17-SHZ-BAR  ER_1000005264_MORV-17-SHZ-BAR
# 79  ER_2000003439_MORV-19-SHZ-MCV          ER_2000003740_BRSHINV
#
#                                           Description            varietal  \
# 0    Atticus Premium Museum<br>Chardonnay 2010  750mL          Chardonnay
# 1    Flying Fish Cove 2 Passions<br>Cabernet Sauvi...  Cabernet Sauvignon
# 2    The Remarkable State Dame<br>Ruby Sparkling.....              Shiraz
# 3    Zonte's Footstep Age Of<br>Enlightenment... 7...              Shiraz
# 4    Epic Negociants The<br>Apollonian Mclaren... ...  Cabernet Sauvignon
# ..                                                ...                 ...
# 75   Caels Gate Handpicked<br>Cabernet Sauvignon.....  Cabernet Sauvignon
# 76        Byron & Harold Tandem Shiraz<br>2018  750mL              Shiraz
# 77   Quarry Collection Coonawarra<br>Shiraz 2019  ...              Shiraz
# 78     Monterra Reserve Barossa<br>Shiraz 2017  750mL              Shiraz
# 79          Beach Road Wines Classic<br>Shiraz  750mL              Shiraz
#
#    webbottleclosure  Prices.promoprice.BeforePromotion  \
# 0         Screw Cap                              510.0
# 1         Screw Cap                              660.0
# 2              Cork                              216.6
# 3         Screw Cap                              360.0
# 4         Screw Cap                              360.0
# ..              ...                                ...
# 75        Screw Cap                                NaN
# 76        Screw Cap                                NaN
# 77        Screw Cap                                NaN
# 78        Screw Cap                                NaN
# 79        Screw Cap                                NaN
#
#     Prices.promoprice.AfterPromotion  Savings
# 0                              285.0    225.0
# 1                              450.0    210.0
# 2                               20.0    196.6
# 3                              180.0    180.0
# 4                              180.0    180.0
# ..                               ...      ...
# 75                               NaN      NaN
# 76                               NaN      NaN
# 77                               NaN      NaN
# 78                               NaN      NaN
# 79                               NaN      NaN
#
# [80 rows x 8 columns]

# %%
from datetime import date, timedelta  
yesterday = date.today() - timedelta(days=1) 
today = date.today()   
file_yes = "Match_results" + yesterday.strftime("%Y%m%d") + ".csv" 
file_tod = "Match_results" + today.strftime("%Y%m%d") + ".csv"
df1 = pd.read_csv(file_yes).iloc[:, 1:]
df2 = pd.read_csv(file_tod).iloc[:, 1:]
df_diff = pd.concat([df1,df2]).drop_duplicates(keep=False)

matches = df_diff
matches.reset_index(drop=True, inplace=True)

final = matches.style.format({'Stockcode_x': make_clickable, 'Stockcode_y': make_clickable, }) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .hide_index()


# Now complete list
myst.reset_index(drop=True, inplace=True)

final_myst = myst.style.format({'Stockcode': make_clickable }) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .hide_index()


#writing HTML Content
heading = '<h1> Mystery Wines</h1>'
subheading = '<h3> Matched </h3>'
# Using .now() from datetime library to add Time stamp
now = datetime.now()
current_time = now.strftime("%m/%d/%Y %H:%M:%S")
header = '<div class="top">' + heading + subheading +'</div>'
footer = '<div class="bottom"> <h3> This Report has been Generated on'+ current_time +'</h3> </div>'
content = final
content_2 = final_myst
# Concating everything to a single string

html = header + content.render() + footer
html_file = "Match_new.html"
with open(html_file,'w+') as file:
    file.write(html)


html = header + content_2.render()  + footer
html_file = "All_deals.html"
with open(html_file,'w+') as file:
    file.write(html)

# %%
# Out:
#    Stockcode_x  Stockcode_y  \
# 0   MYSTERY444       873553
# 1   MYSTERY351        58559
# 2    MYSTERY51       447353
# 3   MYSTERY243       802641
# 4   MYSTERY575       122411
# 5   MYSTERY555        82559
# 6   MYSTERY566       118635
# 7   MYSTERY202        82841
# 8   MYSTERY568        60717
# 9   MYSTERY529        82057
# 10  MYSTERY422        78746
# 11  MYSTERY470        83279
# 12  MYSTERY472        82841
# 13  MYSTERY564        87923
# 14  MYSTERY516        86323
# 15  MYSTERY338       816180
# 16  MYSTERY431        55000
# 17  MYSTERY535        76922
# 18  MYSTERY429       503399
# 19  MYSTERY194       702510
# 20  MYSTERY519        85113
# 21  MYSTERY404        43511
# 22  MYSTERY548       481250
# 23  MYSTERY372        65650
# 24  MYSTERY394        54986
# 25  MYSTERY502        64227
# 26  MYSTERY463        75897
# 27  MYSTERY242       663925
# 28  MYSTERY565       127157
# 29  MYSTERY588        62857
# 30  MYSTERY507        76716
# 31  MYSTERY572        80545
# 32  MYSTERY544        63658
#
#                                           Description                varietal  \
# 0    Haselgrove Seanair Mclaren<br>Vale Shiraz 201...                  Shiraz
# 1    Shottesbrooke Punch Reserve<br>Cabernet Sauvi...      Cabernet Sauvignon
# 2    Wills Domain Cuvée D'élevage<br>Cabernet Sauv...      Cabernet Sauvignon
# 3    Sorby Adams The Reverend<br>Canon Cabernet......         Cabernet Shiraz
# 4    Monterra Reserve Mclaren<br>Vale Shiraz 2018....                  Shiraz
# 5     Merite Single Vineyard<br>Wrattonbully... 750mL      Cabernet Sauvignon
# 6    Chateau Tanunda Terroirs Of<br>The Barossa......                  Shiraz
# 7    The Sands Mornington<br>Peninsula Pinot... 750mL              Pinot Noir
# 8    Epic Negociants Black Label<br>The Ridge Marg...              Chardonnay
# 9    Hare's Chase Cellar Reserve<br>Barossa Valley...  Grenache Shiraz Mataro
# 10   Chateau Tanunda Noble Baron<br>Barossa Cabern...      Cabernet Sauvignon
# 11         The Sands Mornington<br>Peninsula... 750mL              Chardonnay
# 12   The Sands Mornington<br>Peninsula Pinot... 750mL              Pinot Noir
# 13          Eden Hall Reserve Riesling<br>2019  750mL                Riesling
# 14   Jilyara Heath Road Margaret<br>River Malbec  ...                  Malbec
# 15   Bimbadgen Estate Hunter<br>Valley Shiraz 2015...                  Shiraz
# 16   Woodvale Coles Farm Clare<br>Valley Shiraz 20...                  Shiraz
# 17   Byron & Harold Terrane<br>Margaret River... 7...      Cabernet Sauvignon
# 18   St John's Road Prayer Garden<br>Grenache 2018...                Grenache
# 19   Kangarilla Road The Side<br>Road Mclaren Vale...                  Shiraz
# 20   Honeywood Estate Margaret<br>River Shiraz 201...                  Shiraz
# 21   Wills Domain Block 3<br>Cabernet Sauvignon......      Cabernet Sauvignon
# 22   Richard Hamilton Burton's<br>Vineyard Mclaren...                Grenache
# 23   Auld Family Wines Langhorne<br>Creek Strawbri...      Cabernet Sauvignon
# 24   Woodvale Orchard Road<br>Cabernet Sauvignon.....      Cabernet Sauvignon
# 25   Peos Estate Four Jacks<br>Cabernet Sauvignon....      Cabernet Sauvignon
# 26   Richard Hamilton Colton's<br>Mclaren Vale Gsm...                     GSM
# 27            Gibson My Darling Merlot<br>2017  750mL                  Merlot
# 28   Irvine Spring Hill Eden<br>Valley Riesling......                Riesling
# 29   Shingleback Kitchen Garden<br>Mataro 2016  750mL                  Mataro
# 30   Nannup Estate Firetower<br>Cabernet Sauvignon...      Cabernet Sauvignon
# 31   Arowhana Marlborough<br>Sauvignon Blanc... 750mL         Sauvignon Blanc
# 32        Austins & Co. Geelong Shiraz<br>2016  750mL                  Shiraz
#
#     Prices.promoprice.BeforePromotion  Prices.promoprice.AfterPromotion  \
# 0                               89.99                              35.0
# 1                               59.99                              10.0
# 2                               74.99                              30.0
# 3                               74.99                              30.0
# 4                               84.99                              45.0
# 5                               59.99                              30.0
# 6                               59.99                              30.0
# 7                               44.99                              15.0
# 8                               44.99                              20.0
# 9                               39.99                              15.0
# 10                              49.99                              25.0
# 11                              44.99                              22.0
# 12                              44.99                              22.0
# 13                              34.99                              15.0
# 14                              31.99                              14.0
# 15                              29.99                              12.0
# 16                              34.99                              18.0
# 17                              31.99                              15.0
# 18                              29.99                              15.0
# 19                              24.99                              10.0
# 20                              29.99                              15.0
# 21                              35.99                              22.0
# 22                              28.99                              15.0
# 23                              23.99                              10.0
# 24                              24.99                              12.0
# 25                              20.99                               8.0
# 26                              21.99                              10.0
# 27                              24.99                              14.9
# 28                              19.99                              12.0
# 29                              24.99                              19.9
# 30                                NaN                               NaN
# 31                                NaN                               NaN
# 32                                NaN                               NaN
#
#     Savings
# 0     54.99
# 1     49.99
# 2     44.99
# 3     44.99
# 4     39.99
# 5     29.99
# 6     29.99
# 7     29.99
# 8     24.99
# 9     24.99
# 10    24.99
# 11    22.99
# 12    22.99
# 13    19.99
# 14    17.99
# 15    17.99
# 16    16.99
# 17    16.99
# 18    14.99
# 19    14.99
# 20    14.99
# 21    13.99
# 22    13.99
# 23    13.99
# 24    12.99
# 25    12.99
# 26    11.99
# 27    10.09
# 28     7.99
# 29     5.09
# 30      NaN
# 31      NaN
# 32      NaN

# %%
from datetime import date, timedelta  
yesterday = date.today() - timedelta(days=1) 
today = date.today()   
file_yes = "Match_results" + yesterday.strftime("%Y%m%d") + ".csv" 
file_tod = "Match_results" + today.strftime("%Y%m%d") + ".csv"
df1 = pd.read_csv(file_yes).iloc[:, 1:]
df2 = pd.read_csv(file_tod).iloc[:, 1:]
df_diff = pd.concat([df1,df2]).drop_duplicates(keep=False)

matches = df_diff
matches.reset_index(drop=True, inplace=True)

final = matches.style.format({'Stockcode_x': make_clickable, 'Stockcode_y': make_clickable, }) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .hide_index()


# Now complete list
myst.reset_index(drop=True, inplace=True)

final_myst = myst.style.format({'Stockcode': make_clickable }) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .bar(subset=['Savings'], align='mid', color=['#5fba7d']) \
    .hide_index()


#writing HTML Content
heading = '<h1> Mystery Wines</h1>'
subheading = '<h3> Matched </h3>'
# Using .now() from datetime library to add Time stamp
now = datetime.now()
current_time = now.strftime("%m/%d/%Y %H:%M:%S")
header = '<div class="top">' + heading + subheading +'</div>'
footer = '<div class="bottom"> <h3> This Report has been Generated on'+ current_time +'</h3> </div>'
content = final
content_2 = final_myst
# Concating everything to a single string

html = header + content.render() + footer
html_file = "Match_new.html"
with open(html_file,'w+') as file:
    file.write(html)


html = header + content_2.render()  + footer
html_file = "All_deals.html"
with open(html_file,'w+') as file:
    file.write(html)

# %%
df_diff
# Out:
#                        Stockcode_x                    Stockcode_y  \
# 0                       MYSTERY444                         873553
# 1                       MYSTERY351                          58559
# 2                        MYSTERY51                         447353
# 3                       MYSTERY243                         802641
# 4                       MYSTERY575                         122411
# ..                             ...                            ...
# 108     ER_2000003499_MYSTERYMCS19          ER_2000003499_9269708
# 109                     MYSTERY400                          76525
# 110  ER_2000003439_MORV-17-SHZ-BAR      ER_2000003129_QUARRYSHZ18
# 111  ER_2000003439_MORV-17-SHZ-BAR  ER_1000005264_MORV-17-SHZ-BAR
# 112  ER_2000003439_MORV-19-SHZ-MCV          ER_2000003740_BRSHINV
#
#                                            Description            varietal  \
# 0     Haselgrove Seanair Mclaren<br>Vale Shiraz 201...              Shiraz
# 1     Shottesbrooke Punch Reserve<br>Cabernet Sauvi...  Cabernet Sauvignon
# 2     Wills Domain Cuvée D'élevage<br>Cabernet Sauv...  Cabernet Sauvignon
# 3     Sorby Adams The Reverend<br>Canon Cabernet......     Cabernet Shiraz
# 4     Monterra Reserve Mclaren<br>Vale Shiraz 2018....              Shiraz
# ..                                                 ...                 ...
# 108   Caels Gate Handpicked<br>Cabernet Sauvignon.....  Cabernet Sauvignon
# 109        Byron & Harold Tandem Shiraz<br>2018  750mL              Shiraz
# 110   Quarry Collection Coonawarra<br>Shiraz 2019  ...              Shiraz
# 111     Monterra Reserve Barossa<br>Shiraz 2017  750mL              Shiraz
# 112          Beach Road Wines Classic<br>Shiraz  750mL              Shiraz
#
#      Prices.promoprice.BeforePromotion  Prices.promoprice.AfterPromotion  \
# 0                                89.99                              35.0
# 1                                59.99                              10.0
# 2                                74.99                              30.0
# 3                                74.99                              30.0
# 4                                84.99                              45.0
# ..                                 ...                               ...
# 108                                NaN                               NaN
# 109                                NaN                               NaN
# 110                                NaN                               NaN
# 111                                NaN                               NaN
# 112                                NaN                               NaN
#
#      Savings webbottleclosure
# 0      54.99              NaN
# 1      49.99              NaN
# 2      44.99              NaN
# 3      44.99              NaN
# 4      39.99              NaN
# ..       ...              ...
# 108      NaN        Screw Cap
# 109      NaN        Screw Cap
# 110      NaN        Screw Cap
# 111      NaN        Screw Cap
# 112      NaN        Screw Cap
#
# [113 rows x 8 columns]

# %%
wide
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e701552b11bb> in <module>
# ----> 1 wide
#
# NameError: name 'wide' is not defined

# %%
def load_n_explode(file_res="API_results_" + time.strftime("%Y%m%d") + ".csv"):
    # file_res = "API_results_20210823.csv"
    my_df = pd.read_csv(file_res, error_bad_lines=False)

    ## Categories
    # my_df["Categories"]
    # Willnjust keep 2 levels.
    my_df["Categories"] = my_df["Categories"].map(eval, na_action='ignore')
    new_df = my_df["Categories"].apply(pd.Series)
    my_df["Categories"] = new_df[0].apply(pd.Series).UrlFriendlyName
    my_df["Sub_Categories"] = new_df[1].apply(pd.Series).UrlFriendlyName


    ###********NEW> LIMIT TO WINES ONLY
    my_df = my_df[my_df['Categories'].isin(['red-wine', 'white-wine'])]
    
    ## WORK AROUND> NOT SURE WHY. TODO
    my_df = my_df[my_df['Stockcode'] != 'ER_2000003422_RX2386']
    my_df = my_df[my_df['Stockcode'] != 'ER_1000004375_CALSG16']


    ## Reviews
    my_df["Reviews"] = my_df["Reviews"].map(eval, na_action='ignore')
    # Try with first 2 reviews
    new_df = my_df["Reviews"].apply(pd.Series)
    # First
    my_df["Review1_auth"] = new_df[0].apply(pd.Series).author.apply(pd.Series).Value
    my_df["Review1_authorcontent"] = new_df[0].apply(pd.Series).authorcontent.apply(pd.Series).Value
    my_df["Review1_points"] = new_df[0].apply(pd.Series).points.apply(pd.Series).Value
    try:
        my_df["Review1_source"] = new_df[0].apply(pd.Series).source.apply(pd.Series).Value
    except:
        print("No source1")
    try:    
        my_df["Review1_text"] = new_df[0].apply(pd.Series).text.apply(pd.Series).Value
    except:
        print("No text1")
    try:
        my_df["Review1_vintage"] = new_df[0].apply(pd.Series).vintage.apply(pd.Series).Value
    except:
        print("No vintage1")
    # Second
    my_df["Review2_auth"] = new_df[1].apply(pd.Series).author.apply(pd.Series).Value
    my_df["Review2_authorcontent"] = new_df[1].apply(pd.Series).authorcontent.apply(pd.Series).Value
    my_df["Review2_points"] = new_df[1].apply(pd.Series).points.apply(pd.Series).Value
    try:
        my_df["Review2_source"] = new_df[1].apply(pd.Series).source.apply(pd.Series).Value
    except:
        print("No source2")
    try:
        my_df["Review2_text"] = new_df[1].apply(pd.Series).text.apply(pd.Series).Value
    except:
        print("No text2 ")
    try:
        my_df["Review2_vintage"] = new_df[1].apply(pd.Series).vintage.apply(pd.Series).Value
    except:
        print("No review2")
    
    # Drop reviews
    my_df = my_df.drop('Reviews', 1)

    # Illl make a deep copy for later
    full_df = copy.deepcopy(my_df)
    # full_df = full_df

    # Additional details
    my_df["AdditionalDetails"] = my_df["AdditionalDetails"].map(eval, na_action='ignore')
    # Can't use nested lists of JSON objects in pd.json_normalize
    my_df = my_df.explode(column="AdditionalDetails").reset_index(drop=True)

    # Hacky, but it works... so we wont be touching this stuff!
    add_df = pd.DataFrame(pd.json_normalize(my_df["AdditionalDetails"]))
    del add_df["DisplayName"]
    df = pd.concat([my_df, add_df], axis=1)
    df = df.pivot(index='Stockcode', columns='Name', values='Value').reset_index().drop_duplicates(subset=['Stockcode'],
                                                                                                   keep=False)

      
    # Check point, and also a way to get rid of headers
    newdf = pd.merge(full_df, df, on='Stockcode')
    newdf["Mystery"] = newdf["Description"].str.contains("Wraps")
    # This is an old secret seleciton one. Only two, so will drop them
    newdf = newdf[~newdf["Description"].str.contains("Secret Selection")]
    newdf = newdf[~newdf["Stockcode"].str.contains("672366")]
    # newdf = newdf.drop_duplicates(subset=['Stockcode'], keep=False)
    
    # Dropping a few columns we dont want 
    newdf = newdf.drop('ProductTags', 1)
    newdf = newdf.drop('ProductSashes', 1)
    newdf = newdf.drop('UniqueSellingProposition', 1)
    newdf = newdf.drop('ImageVariants', 1)
    newdf = newdf.drop('AvailablePackTypes', 1)
    newdf = newdf.drop('GroupedDetails.image', 1)
    try:
        newdf = newdf.drop('GroupedDetails.video', 1)
    except:
        print("No groupdetails video to remove")
    newdf = newdf.drop('GroupedDetails.workflow', 1)
    newdf = newdf.drop('categoryleafnodeid', 1)
    # Now to drop the additional details, we no need no more.
    newdf = newdf.drop('AdditionalDetails', 1)
    
    return newdf

# %%
#input_file = "API_results_" + time.strftime("%Y%m%d") + ".csv"
os.chdir('/home/stu/code/dans')
input_file = "API_results_20211002.csv"
wide = load_n_explode(input_file)
# Out:
# No source1
# No text1
# No vintage1
# No source2
# No text2
# No review2
# No groupdetails video to remove

# %%
wide
# Out:
#    Unnamed: 0  RecommendedProducts  ProductsInSameOffer  Categories  \
# 0           0                  NaN                  NaN  white-wine
# 1           0                  NaN                  NaN    red-wine
# 2           0                  NaN                  NaN    red-wine
# 3           0                  NaN                  NaN    red-wine
# 4           0                  NaN                  NaN    red-wine
# 5           0                  NaN                  NaN    red-wine
# 6           0                  NaN                  NaN    red-wine
# 7           0                  NaN                  NaN    red-wine
#
#   BackorderMessage  DeliveryOptionsInfo  SavedLists  \
# 0    Limited stock                  NaN         NaN
# 1    Limited stock                  NaN         NaN
# 2    Limited stock                  NaN         NaN
# 3    Limited stock                  NaN         NaN
# 4    Limited stock                  NaN         NaN
# 5    Limited stock                  NaN         NaN
# 6    Limited stock                  NaN         NaN
# 7    Limited stock                  NaN         NaN
#
#                    Stockcode  \
# 0  ER_2000003767_RCSSCHA18X1
# 1  ER_2000003767_RCPBCAS18X1
# 2  ER_2000003767_RCPBSHZ18X1
# 3       ER_2000003422_RX2948
# 4         ER_2000003217_ROSE
# 5        ER_1000005850_PLS15
# 6       ER_2000003422_RX3789
# 7       ER_2000003422_RX6678
#
#                                          Description  \
# 0   Rockcliffe Single Site<br>Chardonnay 2018  750mL
# 1   Rockcliffe Peaceful Bay<br>Cabernet Sauvignon...
# 2      Rockcliffe Peaceful Bay<br>Shiraz 2018  750mL
# 3       Marques De Tezona<br>Tempranillo 2018  750mL
# 4   Miles From Nowhere Margaret<br>River Rose 202...
# 5      Penna Lane Clare Valley<br>Shiraz 2016  750mL
# 6   Kingston Estate Clare Valley<br>Shiraz 2019  ...
# 7           Louis Violland Pinot Noir<br>2018  750mL
#
#                                       SmallImageFile  ...  \
# 0  https://dmdprdecommerceaae.blob.core.windows.n...  ...
# 1  https://dmdprdecommerceaae.blob.core.windows.n...  ...
# 2  https://dmdprdecommerceaae.blob.core.windows.n...  ...
# 3  https://dmdprdecommerceaae.blob.core.windows.n...  ...
# 4  https://dmdprdecommerceaae.blob.core.windows.n...  ...
# 5  https://dmdprdecommerceaae.blob.core.windows.n...  ...
# 6  https://dmdprdecommerceaae.blob.core.windows.n...  ...
# 7  https://dmdprdecommerceaae.blob.core.windows.n...  ...
#
#   webpromomessagestartdt webpromosecondmesgenddt  webregionoforigin  \
# 0                    NaN                     NaN     Great Southern
# 1                    NaN                     NaN                NaN
# 2                    NaN                     NaN                NaN
# 3                    NaN                     NaN                NaN
# 4       2020-12-07 06:00              2021-03-20     Margaret River
# 5    2020-12-09 06:00:00              2021-03-20                NaN
# 6                    NaN                     NaN       Clare Valley
# 7                    NaN                     NaN                NaN
#
#     webstateoforigin                              webtitle  webvintagecurrent  \
# 0  Western Australia           Single Site Chardonnay 2018               2018
# 1                NaN  Peaceful Bay Cabernet Sauvignon 2018               2018
# 2  Western Australia              Peaceful Bay Shiraz 2018               2018
# 3                NaN                      Tempranillo 2018               2018
# 4  Western Australia              Margaret River Rose 2021               2021
# 5                NaN                           Shiraz 2016               2016
# 6    South Australia              Clare Valley Shiraz 2019               2019
# 7                NaN                       Pinot Noir 2018               2018
#
#     webwinebody       webwinemaker  webwinestyle Mystery
# 0           NaN                NaN           NaN   False
# 1           NaN                NaN           NaN   False
# 2           NaN                NaN           NaN   False
# 3           NaN                NaN           NaN   False
# 4  Light Bodied  Frederique Perrin           Dry   False
# 5   Full Bodied                NaN           NaN   False
# 6           NaN                NaN           NaN   False
# 7           NaN                NaN           NaN   False
#
# [8 rows x 137 columns]
